# %% [markdown]
# #Fuel quality data from the Federal Energy Regulatory Commission

# %% [markdown]
# import pandas

# %%
import pandas as pd

# %% [markdown]
# first let us import the data

# %%
url = 'https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'

# %%
raw_df = pd.read_csv(url,error_bad_lines =False)
raw_df
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 0        f1_fuel_1994_12_1_0_7  ...                1.121
# 1       f1_fuel_1994_12_1_0_10  ...                1.120
# 2        f1_fuel_1994_12_2_0_1  ...                1.650
# 3        f1_fuel_1994_12_2_0_7  ...                1.970
# 4       f1_fuel_1994_12_2_0_10  ...                2.570
# ...                        ...  ...                  ...
# 29518  f1_fuel_2018_12_12_0_13  ...                9.030
# 29519   f1_fuel_2018_12_12_1_1  ...                6.950
# 29520  f1_fuel_2018_12_12_1_10  ...                8.990
# 29521  f1_fuel_2018_12_12_1_13  ...                1.110
# 29522  f1_fuel_2018_12_12_1_14  ...               11.680
#
# [29523 rows x 11 columns]

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     29523 non-null  object
#  1   utility_id_ferc1              29523 non-null  int64
#  2   report_year                   29523 non-null  int64
#  3   plant_name_ferc1              29523 non-null  object
#  4   fuel_type_code_pudl           29523 non-null  object
#  5   fuel_unit                     29343 non-null  object
#  6   fuel_qty_burned               29523 non-null  float64
#  7   fuel_mmbtu_per_unit           29523 non-null  float64
#  8   fuel_cost_per_unit_burned     29523 non-null  float64
#  9   fuel_cost_per_unit_delivered  29523 non-null  float64
#  10  fuel_cost_per_mmbtu           29523 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB

# %% [markdown]
# According to the infomation gotten from above we have 29523 rows and 11 columns dataframe which has two rows with integer data type, five float data type and four object data type.

# %%
raw_df.describe()
# Out:
#        utility_id_ferc1  ...  fuel_cost_per_mmbtu
# count      29523.000000  ...         29523.000000
# mean         118.601836  ...            19.304354
# std           74.178353  ...          2091.540939
# min            1.000000  ...           -41.501000
# 25%           55.000000  ...             1.940000
# 50%          122.000000  ...             4.127000
# 75%          176.000000  ...             7.745000
# max          514.000000  ...        359278.000000
#
# [8 rows x 7 columns]

# %%
raw_df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
raw_df.duplicated().any()
# Out:
# False

# %% [markdown]
# let us check for unique values in categorical columns

# %%
raw_df['utility_id_ferc1'].unique()
# Out:
# array([  1,   2,   4,   6,   7,   9,  10,  11,  12,  15,  16,  17,  20,
#         24,  26, 191,  31,   8,  42,  43,  44,  46,  50,  51,  54,  55,
#         38,  73,  81, 127,  19,  36,  61,  63,  64,  68,  70,  72,  74,
#         75,  77,  79,  80,  85,  96,  97,  98,  99,  27,  30,  52, 135,
#         69,  87,  88, 121, 122, 102, 193, 194, 125, 126, 128, 129, 130,
#        131, 132, 134, 137, 141, 142, 143, 145, 117, 146, 150, 151, 157,
#        114, 115, 118, 161, 162, 163, 164, 166, 169, 170, 173, 176, 177,
#        179, 182, 185, 186, 187, 188, 189,  33,  89, 200, 201, 204, 208,
#        159, 119,  25,  49, 108, 155, 100, 107, 144, 116, 136,  67,  82,
#         95, 133, 138, 148, 190,  56, 113,  32, 120, 147, 160, 175,  22,
#         39,  62,  76, 101, 124, 154, 156, 174, 195, 104,  14,  57,  41,
#         45, 149, 213, 210,  29,  94, 230,  71,  21, 202, 244, 226, 227,
#         65, 171, 181, 221, 266, 245, 270, 276, 203, 271, 283, 281, 285,
# ...

# %%
raw_df['plant_name_ferc1'].unique()
# Out:
# array(['rockport', 'rockport total plant', 'gorgas', ...,
#        'airport unit 6', 'wyodak - bhp 20%', 'wygen 3 bhp 52%'],
#       dtype=object)

# %%
raw_df.groupby('plant_name_ferc1')['plant_name_ferc1'].count()
# Out:
# plant_name_ferc1
# (1)sta98                1
# (2) scriba sta. 99      1
# (n) contra costa        1
# (n) pittsburg           1
# (n)(t)moss landing      1
#                        ..
# zimmer- aepgr share     2
# zion                    3
# zorn                   12
# zorn ct                10
# zuni                   17
# Name: plant_name_ferc1, Length: 2315, dtype: int64

# %%
raw_df['fuel_type_code_pudl'].unique()
# Out:
# array(['coal', 'gas', 'nuclear', 'oil', 'waste', 'other'], dtype=object)

# %%
raw_df.groupby('fuel_type_code_pudl')['fuel_type_code_pudl'].count()
# Out:
# fuel_type_code_pudl
# coal        8547
# gas        11486
# nuclear      818
# oil         8064
# other        167
# waste        441
# Name: fuel_type_code_pudl, dtype: int64

# %%
raw_df['fuel_unit'].unique()
# Out:
# array(['ton', 'mcf', 'kgU', 'bbl', 'gramsU', nan, 'mwdth', 'mmbtu',
#        'mwhth', 'gal'], dtype=object)

# %%
raw_df.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %% [markdown]
# let us see the percentage of row with missing values

# %%
((sum([True for idx,row in raw_df.iterrows() if any(row.isnull())]))/raw_df.shape[0])*100
# Out:
# 0.609694136774718

# %% [markdown]
# #Data visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
sns.heatmap(raw_df.corr(), cmap='Reds', annot=True)
plt.title('Correlation Matrix');

# %%
plt.bar(raw_df['report_year'], raw_df['fuel_cost_per_unit_burned'])

plt.xlabel('report_year')
plt.ylabel('fuel_cost_per_unit_burned');

# %%
plt.bar(raw_df['report_year'], raw_df['fuel_cost_per_unit_delivered'])

plt.xlabel('report_year')
plt.ylabel('fuel_cost_per_unit_delivered');

# %%
raw_df.groupby('fuel_type_code_pudl')['fuel_cost_per_unit_burned'].mean()
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
raw_df.groupby

# %% [markdown]
# The percentage change in fuel cost per unit burned in 1998 compared to 1994 for fuel type coal

# %%
coal_fuel_cost_per_unitburn = raw_df[['fuel_cost_per_unit_burned','report_year','fuel_type_code_pudl']][raw_df['fuel_type_code_pudl'] == 'coal']
coal_fuel_cost_per_unitburn
# Out:
#        fuel_cost_per_unit_burned  report_year fuel_type_code_pudl
# 0                         18.590         1994                coal
# 1                         18.580         1994                coal
# 2                         39.720         1994                coal
# 3                         47.210         1994                coal
# 5                         44.240         1994                coal
# ...                          ...          ...                 ...
# 29503                     26.775         2018                coal
# 29510                     14.760         2018                coal
# 29516                     14.760         2018                coal
# 29517                     13.690         2018                coal
# 29521                      3.060         2018                coal
#
# [8547 rows x 3 columns]

# %%
diff_94 = coal_fuel_cost_per_unitburn['fuel_cost_per_unit_burned'][coal_fuel_cost_per_unitburn['report_year']== 1994].max() - coal_fuel_cost_per_unitburn['fuel_cost_per_unit_burned'][coal_fuel_cost_per_unitburn['report_year']== 1994].min()

# %%
diff_98 = coal_fuel_cost_per_unitburn['fuel_cost_per_unit_burned'][coal_fuel_cost_per_unitburn['report_year']== 1998].max() - coal_fuel_cost_per_unitburn['fuel_cost_per_unit_burned'][coal_fuel_cost_per_unitburn['report_year']== 1998].min()

# %%
diff_94
# Out:
# 51.108000000000004

# %%
diff_98
# Out:
# 53.249

# %% [markdown]
# #Skewness and kurtosis

# %%
raw_df.skew(axis = 0)
# Out:
# utility_id_ferc1                  0.605070
# report_year                       0.006953
# fuel_qty_burned                  15.851495
# fuel_mmbtu_per_unit               4.135217
# fuel_cost_per_unit_burned        19.787440
# fuel_cost_per_unit_delivered    105.014227
# fuel_cost_per_mmbtu             171.675535
# dtype: float64

# %%
raw_df.kurt(axis =0)
# Out:
# utility_id_ferc1                    1.088432
# report_year                        -1.145656
# fuel_qty_burned                   651.369450
# fuel_mmbtu_per_unit                55.595695
# fuel_cost_per_unit_burned         485.255851
# fuel_cost_per_unit_delivered    11765.054226
# fuel_cost_per_mmbtu             29489.132594
# dtype: float64
